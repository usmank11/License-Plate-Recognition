# %% [markdown]
# Import Dependencies

# %%
# !pip install easyocr
# !pip install imutils
# !pip install matplotlib
# Out:
# Requirement already satisfied: easyocr in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (1.4.1)
# Requirement already satisfied: torchvision>=0.5 in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from easyocr) (0.11.2)
# Requirement already satisfied: scikit-image in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from easyocr) (0.18.3)
# Requirement already satisfied: python-bidi in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: opencv-python-headless in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from easyocr) (4.5.4.60)
# Requirement already satisfied: PyYAML in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from easyocr) (6.0)
# Requirement already satisfied: numpy in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from easyocr) (1.20.3)
# Requirement already satisfied: Pillow<8.3.0 in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from easyocr) (8.2.0)
# Requirement already satisfied: torch in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from easyocr) (1.10.1)
# Requirement already satisfied: scipy in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from easyocr) (1.7.1)
# Requirement already satisfied: typing-extensions in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from torch->easyocr) (3.10.0.2)
# Requirement already satisfied: six in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from scikit-image->easyocr) (3.4.3)
# Requirement already satisfied: networkx>=2.0 in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from scikit-image->easyocr) (2.6.3)
# Requirement already satisfied: imageio>=2.3.0 in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from scikit-image->easyocr) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from scikit-image->easyocr) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from scikit-image->easyocr) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (3.0.4)
# Requirement already satisfied: imutils in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (0.5.4)
# Requirement already satisfied: matplotlib in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (3.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (8.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: numpy>=1.16 in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: six in /Users/usmankhan/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib) (1.16.0)

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import imutils
import easyocr

# %% [markdown]
# Read Image and apply grayscale and blur

# %%
img = cv2.imread('test1.jpeg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))

# %% [markdown]
# Apply filter and find edges

# %%
bfilter = cv2.bilateralFilter(gray, 11, 17, 17)
edged = cv2.Canny(bfilter, 30, 200)
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))

# %% [markdown]
# Find contours and apply mask

# %%
keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(keypoints)
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

# %%
location = None
for contour in contours:
    approx = cv2.approxPolyDP(contour, 10, True)
    if len(approx) ==4:
        location = approx
        break

# %%
location
# Out:
# array([[[623, 770]],
#
#        [[899, 770]],
#
#        [[903, 838]],
#
#        [[623, 841]]], dtype=int32)

# %%
mask = np.zeros(gray.shape, np.uint8)
new_image = cv2.drawContours(mask, [location], 0, 255, -1)
new_image = cv2.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))

# %%
(x,y) = np.where(mask==255)
(x1,y1) = (np.min(x), np.min(y))
(x2,y2) = (np.max(x), np.max(y))
cropped_image = gray[x1:x2+1, y1:y2+1]

# %%
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %% [markdown]
# Easy OCR to read text

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(cropped_image)
result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[20, 0], [262, 0], [262, 70], [20, 70]], 'BCF 260', 0.9830921832849696)]

# %% [markdown]
# Render

# %%
text = result[0][-2]
font = cv2.FONT_HERSHEY_SIMPLEX
res = cv2.putText(img, text=text, org=(approx[0][0][0], approx[1][0][1]+60), fontFace=font, fontScale=1, color=(0,255,0), thickness=2, lineType=cv2.LINE_AA)
res = cv2.rectangle(img, tuple(approx[0][0]), tuple(approx[2][0]), (0,255,0), 3)
plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))
